# %%
#definfg a bank model 
class Bank:
    def __init__(self ,name , bal ):
        self.name = name 
        self.bal = bal 
    def seeBalance( self):
        print(f"{self.name} balce is {self.bal}")
