# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
df =pd.read_csv('height_weight_data.csv')
df.head()
# Out:
#    Height  Weight
# 0     199      80
# 1     143      48
# 2     194      78
# 3     196      80
# 4     185      72

# %%
plt.scatter(df['Weight'],df['Height'])

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('Height vs Weight')
# Out:
# Text(0.5, 1.0, 'Height vs Weight')

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.997949
# Weight  0.997949  1.000000

# %%
import seaborn as sns 
sns.pairplot(df)

# %%
## indepent and depent faeturs 
X = df[['Weight']]## always make it in 2D arrray 
y = df['Height'] ## this is always in 1 d

# %%
# Out:
# (6, 1) (6,) (6,)

# %%
## stanadarozation
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_train)

# %%
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# APPly Linear Reggression
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# 1. Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# 2. Scale (correct way)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)   # ✅ DO NOT overwrite

# 3. Train
regression.fit(X_train, y_train)

# 4. Predict
y_pred = regression.predict(X_test)

# 5. Check
print(X_test.shape, y_test.shape, y_pred.shape)
# Expected: (6,1), (6,), (6,)
# Out:
# (6, 1) (6,) (6,)

# %%
print(" COFFE",regression.coef_)

print("INTERCEPT",regression.intercept_)
# Out:
#  COFFE [18.73639894]
# INTERCEPT 176.05882352941177

# %%
# Plot teh best fit line ;
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
#Predinct for the /Metrics 
y_pred=regression.predict(X_test)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
print("y_pred:", y_pred.shape)
# Out:
# X_train: (17, 1)
# X_test: (6, 1)
# y_test: (6,)
# y_pred: (6,)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = sqrt(mse)

print("MSE:", mse)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MSE: 2.3768134125640556
# MAE: 1.4141991924629735
# RMSE: 1.541691737204314

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse = sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 2.3768134125640556
# 1.4141991924629735
# 1.541691737204314

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test , y_pred)
print(score)
# Out:
# 0.9920485751461475

# %%
#disply sdjusted R squared 
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9900607189326844

# %%
##ols method 
import statsmodels.api as sm

# %%
regression.predict(scaler.transform([[67]]))
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([174.9674742])
