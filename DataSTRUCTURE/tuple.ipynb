# %%
numbers = tuple([1,2,34,3])
print(numbers)
# Out:
# (1, 2, 34, 3)

# %%
lsi =list((1,2,3,2,1232))
print(lsi)
# Out:
# [1, 2, 3, 2, 1232]

# %%
## Acessing tuple 
numbers[0]
# Out:
# 1

# %%
numbers[0:4]
# Out:
# (1, 2, 34, 3)

# %%
#Tuple operation
numbers [::-1]
# Out:
# (3, 34, 2, 1)

# %%
numbers*3
# Out:
# (1, 2, 34, 3, 1, 2, 34, 3, 1, 2, 34, 3)

# %%
number = (1,3,4,33,4)
a ,*mid = number
print( a, mid)
# Out:
# 1 [3, 4, 33, 4]

# %%
aaa
