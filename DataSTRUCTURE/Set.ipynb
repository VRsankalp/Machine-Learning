# %%
sest1 = ([1,2,3,4,2,1])
print(sest1)
# Out:
# [1, 2, 3, 4, 2, 1]

# %%
sest1.remove(37) 
print(sest1)
# Out:
# [1, 2, 4, 2, 1, 67, 67, 67, 67]

# %%
lo = set[2,2,2,1,1,1,11,1,1,1,1,1]
print(lo)
# Out:
# set[2, 2, 2, 1, 1, 1, 11, 1, 1, 1, 1, 1]

# %%
set1 = set([1,2,1,1,21])
set2 =([34,5,3,3,3,3,3,4,4,5,3])
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 34, 3, 5, 4, 21}
